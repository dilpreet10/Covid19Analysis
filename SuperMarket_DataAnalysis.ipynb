# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('supermarket_sales.csv')

# %%
df.head(50)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
pd.isnull(df).sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.drop(['Date', 'Time'], axis=1, inplace=True)
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0      Ewallet  522.83                 4.761905       26.1415     9.1
# 1         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df[['Unit price','Quantity','Tax 5%','Total']].describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# std      26.494628     2.923431    11.708825   245.885335
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000

# %%
# plotting a bar chart for Gender and it's count
ax = sns.countplot(x = 'Gender',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Branch and it's count
ax = sns.countplot(x = 'Branch',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Customer type and it's count
ax = sns.countplot(x = 'Customer type',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for City and it's count
ax = sns.countplot(x = 'City',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Product line and it's count
ax = sns.countplot(x = 'Product line',data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Payment and it's count
ax = sns.countplot(x = 'Payment',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Total'].sum().sort_values(by='Total', ascending=False)

sns.barplot(x = 'Gender',y= 'Total' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Total'>

# %%
sns.boxplot(x="Branch", y = "Rating" ,data =df).set_title("Ratings by Branch")
# Out:
# Text(0.5, 1.0, 'Ratings by Branch')

# %%
df['Rating'].unique()
# Out:
# array([ 9.1,  9.6,  7.4,  8.4,  5.3,  4.1,  5.8,  8. ,  7.2,  5.9,  4.5,
#         6.8,  7.1,  8.2,  5.7,  4.6,  6.9,  8.6,  4.4,  4.8,  5.1,  9.9,
#         6. ,  8.5,  6.7,  7.7,  7.5,  7. ,  4.7,  7.6,  7.9,  6.3,  5.6,
#         9.5,  8.1,  6.5,  6.1,  6.6,  5.4,  9.3, 10. ,  6.4,  4.3,  4. ,
#         8.7,  9.4,  5.5,  8.3,  7.3,  4.9,  4.2,  9.2,  7.8,  5.2,  9. ,
#         8.8,  6.2,  9.8,  9.7,  5. ,  8.9])

# %%
ageDisSpend = sns.lineplot(x="Total", y = "Rating", data =df)

# %%
#Product Analyis
sns.boxenplot(y = 'Product line', x = 'Quantity', data=df )
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %%
sns.countplot(y = 'Product line', data=df, order = df['Product line'].value_counts().index )
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
sns.boxenplot(y = 'Product line', x = 'Total', data=df )
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
sns.stripplot(y = 'Product line', x = 'Total', hue = 'Gender', data=df)
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
#Payment Analyis by branch
sns.countplot(x="Payment", hue = "Branch", data =df).set_title("Payment Channel by Branch")
# Out:
# Text(0.5, 1.0, 'Payment Channel by Branch')

# %%
#Customer Analysis by branch
sns.countplot(x="Customer type", hue = "Branch", data =df).set_title("Customer Type by Branch")
# Out:
# Text(0.5, 1.0, 'Customer Type by Branch')

# %%
# top 10 most sold products (same thing as above)
fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Invoice ID')['Quantity'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Invoice ID'>

# %%
sales_state = df.groupby(['Product line'], as_index=False)['Total'].sum().sort_values(by='Total', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product line',y= 'Total')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
sales_state = df.groupby(['Invoice ID'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Invoice ID',y= 'Quantity')
# Out:
# <Axes: xlabel='Invoice ID', ylabel='Quantity'>
